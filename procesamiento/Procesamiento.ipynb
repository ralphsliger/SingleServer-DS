# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('archivo1.csv', sep=';', engine='python')
df.head()
# Out:
#        User name              Full name                      E-mail  \
# 0       15324916          juan arroyave    diegaarroyaveg@gmail.com
# 1              0  Prueba Miguel Baquero  pgbarinas@euphoria-net.com
# 2  1.104.867.397        Evelis  Pestana    Omarjose757522@gmail.com
# 3  1.124.057.619          Nelson  Vives       hamayapia@hotmail.com
# 4     1000611768              juan leon          judilemo@gmail.com
#
#         Nickname                   Created Enabled
# 0       15324916  02/02/2014 02:31:41 p.m.     Yes
# 1             -1  14/11/2012 09:10:11 p.m.      No
# 2  not available  24/02/2014 07:51:23 p.m.     Yes
# 3             -1  16/10/2013 10:28:29 p.m.     Yes
# 4     1000611768  09/11/2013 06:23:10 p.m.     Yes

# %%
df2= pd.read_csv('archivo2.csv', sep=";", engine='python')
df2.head()
# Out:
#        User name              Full name       Nickname  \
# 0       15324916          juan arroyave       15324916
# 1              0  Prueba Miguel Baquero             -1
# 2  1.104.867.397        Evelis  Pestana  not available
# 3  1.124.057.619          Nelson  Vives             -1
# 4     1000611768              juan leon     1000611768
#
#                     Created Enabled
# 0  02/02/2014 02:31:41 p.m.     Yes
# 1  14/11/2012 09:10:11 p.m.      No
# 2  24/02/2014 07:51:23 p.m.     Yes
# 3  16/10/2013 10:28:29 p.m.     Yes
# 4  09/11/2013 06:23:10 p.m.     Yes

# %%
# uniendo el dataframe en vertical 
merge_df = [df,df2]
pd.concat(merge_df)
# Out:
# /Users/ralphsliger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                       Created                         E-mail Enabled  \
# 0    02/02/2014 02:31:41 p.m.       diegaarroyaveg@gmail.com     Yes
# 1    14/11/2012 09:10:11 p.m.     pgbarinas@euphoria-net.com      No
# 2    24/02/2014 07:51:23 p.m.       Omarjose757522@gmail.com     Yes
# 3    16/10/2013 10:28:29 p.m.          hamayapia@hotmail.com     Yes
# 4    09/11/2013 06:23:10 p.m.             judilemo@gmail.com     Yes
# 5    02/04/2014 02:26:55 p.m.           clamiloq@hotmail.com     Yes
# 6    25/01/2014 01:34:50 p.m.        dayannareinel@gmail.com     Yes
# 7    25/01/2014 09:31:34 a.m.     franjazago1620@hotmail.com     Yes
# ...

# %%
#leer json
df_json = pd.read_json('data.json', orient='columns')
df_json.head()
# Out:
#     integer            datetime  category
# 0         5 2015-01-01 00:00:00         0
# 1         5 2015-01-01 00:00:01         0
# 10        5 2015-01-01 00:00:10         0
# 11        5 2015-01-01 00:00:11         0
# 12        8 2015-01-01 00:00:12         0

# %%
#leer html
df_html= pd.read_html('data.html')
df_html
# Out:
# [                      0                   1     2
#  0  Programming Language             Creator  Year
#  1                     C      Dennis Ritchie  1972
#  2                Python    Guido Van Rossum  1989
#  3                  Ruby  Yukihiro Matsumoto  1995]

# %%
#leer xml, ref: https://gokhanatil.com/2017/11/python-for-data-science-importing-xml-to-pandas-dataframe.html

import xml.etree.cElementTree as et
import pandas as pd
 
def getvalueofnode(node):
    """ return node text or None """
    return node.text if node is not None else None
 
 
def main():
    parsed_xml = et.parse("data.xml")
    dfcols = ['name', 'email', 'phone', 'street']
    df_xml = pd.DataFrame(columns=dfcols)
 
    for node in parsed_xml.getroot():
        name = node.attrib.get('name')
        email = node.find('email')
        phone = node.find('phone')
        street = node.find('address/street')
 
        df_xml = df_xml.append(
            pd.Series([name, getvalueofnode(email), getvalueofnode(phone),
                       getvalueofnode(street)], index=dfcols),
            ignore_index=True)
 
    print (df_xml)
 
main()
# Out:
#      name             email     phone        street
# 0  gokhan  gokhan@gmail.com  555-1234          None
# 1    mike    mike@gmail.com      None          None
# 2    john    john@gmail.com  555-4567          None
# 3   david              None  555-6472  Fifth Avenue
